# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

print(f"Versión de Pandas: {pd.__version__}")
print(f"Versión de NumPy: {np.__version__}")
# Out:
# Versión de Pandas: 2.3.0+4.g1dfc98e16a
# Versión de NumPy: 2.0.2

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

print(f"Versión de Pandas: {pd.__version__}")
print(f"Versión de NumPy: {np.__version__}")
# Out:
# Versión de Pandas: 2.3.0+4.g1dfc98e16a
# Versión de NumPy: 2.0.2

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

print(f"Versión de Pandas: {pd.__version__}")
print(f"Versión de NumPy: {np.__version__}")

# Configuración para mejor visualización
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)
# Out:
# Versión de Pandas: 2.3.0+4.g1dfc98e16a
# Versión de NumPy: 2.0.2

# %%
 # Cargar datos
try:
    df_pozos = pd.read_csv('/workspaces/AdP-basic-Zenaida20/Sesion11/datos/pozos_multinivel.csv')
    print("✅ Datos cargados exitosamente")
except FileNotFoundError:
    print("❌ Error: No se encontró el archivo de datos")
   
    
print(f"📊 Forma del DataFrame: {df_pozos.shape}")

print(f"📋 Columnas: {list(df_pozos.columns)}")
# Out:
# ✅ Datos cargados exitosamente
# 📊 Forma del DataFrame: (27, 13)
# 📋 Columnas: ['campo', 'pozo', 'fecha', 'profundidad', 'presion_cabeza', 'temperatura', 'produccion_diaria', 'agua_cut', 'gas_oil_ratio', 'estado_pozo', 'tipo_pozo', 'operador', 'region']

# %%
def main():
    print("=== DEMOSTRACIÓN 1: INDEXACIÓN AVANZADA Y MULTIINDEX ===\n")
    
    # Cargar datos
    try:
        df_pozos = pd.read_csv('datos/pozos_multinivel.csv')
        print("✅ Datos cargados exitosamente")
    except FileNotFoundError:
        print("❌ Error: No se encontró el archivo de datos")
        return
    
    print(f"📊 Forma del DataFrame: {df_pozos.shape}")
    print(f"📋 Columnas: {list(df_pozos.columns)}")
    
    # ===================================================================
    # 1. CREACIÓN DE MULTIINDEX
    # ===================================================================
    print("\n" + "="*60)
    print("1. CREACIÓN DE MULTIINDEX")
    print("="*60)
    
    # Crear MultiIndex con campo, pozo y fecha
    df_multi = df_pozos.set_index(['campo', 'pozo', 'fecha'])
    
    print("🔧 MultiIndex creado con niveles: campo → pozo → fecha")
    print(f"📏 Forma: {df_multi.shape}")
    print(f"📏 Forma: {df_multi.columns}")
    print(f"🏗️  Niveles: {df_multi.index.names}")
    
    # Mostrar estructura del MultiIndex
    print("\n📋 Estructura del MultiIndex:")
    print(df_multi.head(10))

# %%
# Archivo: lab_01_indexacion_multinivel.py
"""
Laboratorio 1: Indexación Multinivel y Jerarquías
Objetivo: Dominar las técnicas de indexación multinivel y operaciones jerárquicas
          con DataFrames para análisis avanzado de datos petroleros.

Este laboratorio utiliza datos del archivo pozos_multinivel.csv
"""
import pandas as pd
import numpy as np
from datetime import datetime

def main():
    # Cargar datos de ejemplo
try:
        df_pozos = pd.read_csv('datos/pozos_multinivel.csv')
        print("Datos cargados exitosamente")
        print(f"Forma del DataFrame: {df_pozos.shape}")
        print(f"Columnas: {list(df_pozos.columns)}")
except FileNotFoundError:
        print("Error: No se encontró el archivo 'datos/pozos_multinivel.csv'")
        return
except Exception as e:
        print(f"Error al cargar datos: {e}")
        return
    
    print("\n=== Laboratorio 1: Indexación Multinivel y Jerarquías ===\n")
    
    # EJERCICIO 1: Crear MultiIndex jerárquico
    # -------------------------------------------------------------------
    #Crea un MultiIndex usando las columnas 'campo', 'pozo' y 'fecha'
    
    pd.MultiIndex.from_arrays(
        arrays=[df_pozos['campo'], df_pozos['pozo'], pd.to_datetime(df_pozos['fecha'])],
        names=['campo', 'pozo', 'fecha']
    )       
    
    print("Ejercicio 1: Crear MultiIndex jerárquico")
    
    
    # Sugerencia: Usa pd.MultiIndex.from_arrays() o set_index()
    
    # Código de ejemplo para empezar: # df_multi = df_pozos.copy() 
    # df_multi = df_pozos.copy()
    # df_multi = df_multi.set_index(['campo', 'pozo', 'fecha'])
    df_multi = pd.MultiIndex.from_arrays(
         arrays=[df_pozos['campo'], df_pozos['pozo'], pd.to_datetime(df_pozos['fecha'])],
         names=['campo', 'pozo', 'fecha']
     ) 

    # Imprimir resultados (no modificar)
try:
        print(f"Forma del DataFrame con MultiIndex: {df_multi.shape}")
        print("Niveles del MultiIndex:")
        for i, level in enumerate(df_multi.index.names):
            print(f"  Nivel {i}: {level}")
        print("\nPrimeras filas del DataFrame con MultiIndex:")
        print(df_multi.head())
except NameError:
        print("No se ha implementado el MultiIndex")
    
    print("\n" + "-"*50 + "\n")

# EJERCICIO 2: Selección jerárquica avanzada
    # -------------------------------------------------------------------
    # Utiliza el DataFrame con MultiIndex para realizar selecciones jerárquicas:
    # a) Selecciona todos los datos del 'Campo Libertad' 
campo_libertad = df_multi.loc['Campo Libertad']
    # b) Selecciona los datos del pozo 'LIB-001' en el 'Campo Libertad'
pozo_lib001 = df_multi.loc[('Campo Libertad', 'LIB-001')]
    
    # c) Selecciona los datos del 'Campo Libertad', pozo 'LIB-001' para '2024-01-01'
 fecha_especifica = df_multi.loc[('Campo Libertad', 'LIB-001', '2024-01-01')] 
    # Imprimir resultados (no modificar)
    try:
        print("a) Datos del Campo Libertad:")
        print(f"   Filas: {len(campo_libertad)}")
        print(f"   Pozos únicos: {campo_libertad.index.get_level_values('pozo').unique()}") 
  
    print("Ejercicio 2: Selección jerárquica avanzada")
        
    # Imprimir resultados (no modificar)
    try:
        print("a) Datos del Campo Libertad:")
        print(f"   Filas: {len(campo_libertad)}")
        print(f"   Pozos únicos: {campo_libertad.index.get_level_values('pozo').unique()}")
        
        print("\nb) Datos del pozo LIB-001 en Campo Libertad:")
        print(f"   Filas: {len(pozo_lib001)}")
        print(f"   Fechas: {list(pozo_lib001.index.get_level_values('fecha'))}")
        
        print("\nc) Datos específicos de fecha:")
        print(f"   Producción diaria: {fecha_especifica['produccion_diaria']} BPD")
        print(f"   Presión de cabeza: {fecha_especifica['presion_cabeza']} PSI")
    except NameError:
        print("No se han implementado las selecciones jerárquicas")
    
    print("\n" + "-"*50 + "\n")
    
    # EJERCICIO 3: Operaciones por niveles del MultiIndex
    # -------------------------------------------------------------------
    # Realiza operaciones agrupadas por diferentes niveles del MultiIndex:
    # a) Calcula la producción promedio por campo
    # b) Calcula la producción promedio por pozo dentro de cada campo
    # c) Encuentra el pozo con mayor producción promedio en cada campo
    
    print("Ejercicio 3: Operaciones por niveles del MultiIndex")
    
    # TODO: Implementa las operaciones por niveles aquí
    
    # a) Producción promedio por campo
produccion_por_campo = df_multi.groupby(level='campo')['produccion_diaria'].mean()
    
    # b) Producción promedio por pozo (manteniendo la jerarquía)
produccion_por_pozo = df_multi.groupby(level=['campo', 'pozo'])['produccion_diaria'].mean()
    
    # c) Pozo con mayor producción por campo
mejor_pozo_por_campo = df_multi.groupby(level='campo')['produccion_diaria'].agg(['mean', 'idxmax'])
    
    # Imprimir resultados (no modificar)
    try:
        print("a) Producción promedio por campo:")
        for campo, produccion in produccion_por_campo.items():
            print(f"   {campo}: {produccion:.2f} BPD")
        
        print("\nb) Producción promedio por pozo:")
        for (campo, pozo), produccion in produccion_por_pozo.items():
            print(f"   {campo} - {pozo}: {produccion:.2f} BPD")
        
        print("\nc) Mejor pozo por campo:")
        for campo in df_multi.index.get_level_values('campo').unique():
            mejor_idx = mejor_pozo_por_campo.loc[campo, 'idxmax']
            mejor_pozo = mejor_idx[1]  # El pozo está en el segundo nivel
            mejor_produccion = mejor_pozo_por_campo.loc[campo, 'mean']
            print(f"   {campo}: {mejor_pozo} ({mejor_produccion:.2f} BPD)")
    except NameError:
        print("No se han implementado las operaciones por niveles")
    
    print("\n" + "-"*50 + "\n")
    
    # EJERCICIO 4: Reestructuración de datos (Pivot y Stack/Unstack)
    # -------------------------------------------------------------------
    # Utiliza técnicas de reestructuración para crear vistas diferentes de los datos:
    # a) Crea un pivot table con campos como filas, pozos como columnas y producción como valores
df_pivot = df_pozos.pivot_table(
index='campo', 
columns='pozo', 
values='produccion_diaria', 
aggfunc='mean'
     )
    # b) Usa unstack() para convertir el nivel 'pozo' en columnas
df_unstacked = df_multi['produccion_diaria'].unstack(level='pozo')  

    # c) Usa stack() para convertir columnas de nuevo a niveles del índice
df_stacked = df_unstacked.stack()   
    # Imprimir resultados (no modificar)    
    try:
        print("a) Pivot table (producción promedio por campo y pozo):")
        print(df_pivot)
        
        print("\nb) DataFrame unstacked (pozos como columnas):")
        print(df_unstacked)
        
        print("\nc) DataFrame re-stacked:")
        print(df_stacked.head(10))
    except NameError:
        print("No se han implementado las operaciones de reestructuración")
    
    print("\n" + "-"*50 + "\n")
    
    # EJERCICIO 5: Análisis comparativo avanzado
    # -------------------------------------------------------------------
    # Realiza un análisis comparativo sofisticado usando las técnicas aprendidas:
    # a) Calcula la eficiencia operacional por campo (producción/horas operación)
df_multi['eficiencia'] = df_multi['produccion_diaria'] / df_multi['horas_operacion']
eficiencia_por_campo = df_multi.groupby(level='campo')['eficiencia'].mean()

    # b) Identifica los pozos con mayor variabilidad en producción
variabilidad_pozos = df_multi.groupby(level=['campo', 'pozo'])['produccion_diaria'].agg(['mean', 'std'])
variabilidad_pozos['coeficiente_variacion'] = variabilidad_pozos['std'] / variabilidad_pozos['mean']
    

    # c) Crea un ranking de campos por rendimiento general
ranking_campos = df_multi.groupby(level='campo').agg({
'produccion_diaria': ['mean', 'sum'],
'eficiencia_bomba': 'mean',
 'agua_cut': 'mean'
    }).round(2)

    
    # Imprimir resultados (no modificar)
try:
        print("a) Eficiencia operacional por campo:")
        for campo, eficiencia in eficiencia_por_campo.items():
            print(f"   {campo}: {eficiencia:.2f} BPD/hora")
        
        print("\nb) Pozos con mayor variabilidad (CV > 0.1):")
        pozos_variables = variabilidad_pozos[variabilidad_pozos['coeficiente_variacion'] > 0.1]
        for (campo, pozo), datos in pozos_variables.iterrows():
            print(f"   {campo} - {pozo}: CV = {datos['coeficiente_variacion']:.3f}")
        
        print("\nc) Ranking de campos por rendimiento:")
        print(ranking_campos)
except NameError:
        print("No se ha implementado el análisis comparativo")
    
print("\n" + "-"*50 + "\n")
    
    # EJERCICIO 6: Operaciones condicionales con MultiIndex
    # -------------------------------------------------------------------
    # Aplica transformaciones condicionales usando el MultiIndex:
    # a) Marca los pozos con producción por encima del promedio de su campo
df_multi['sobre_promedio'] = df_multi.groupby(level='campo')['produccion_diaria'].transform(
    lambda x: x > x.mean()
    )
    # b) Calcula la desviación estandarizada de producción por campo
df_multi['produccion_normalizada'] = df_multi.groupby(level='campo')['produccion_diaria'].transform(
    lambda x: (x - x.mean()) / x.std()
    )   
    # c) Identifica anomalías (valores fuera de 2 desviaciones estándar)
anomalias = df_multi[abs(df_multi['produccion_normalizada']) > 2]           
    
    print("Ejercicio 6: Operaciones condicionales con MultiIndex")
    
    # Imprimir resultados (no modificar)
    try:
        print("a) Pozos con producción sobre el promedio de su campo:")
        pozos_sobre_promedio = df_multi[df_multi['sobre_promedio'] == True]
        for (campo, pozo, fecha), datos in pozos_sobre_promedio.iterrows():
            print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD")
        
        print(f"\nb) Estadísticas de normalización:")
        print(f"   Media: {df_multi['produccion_normalizada'].mean():.3f}")
        print(f"   Desv. Est.: {df_multi['produccion_normalizada'].std():.3f}")
        
        print(f"\nc) Anomalías detectadas: {len(anomalias)} registros")
        for (campo, pozo, fecha), datos in anomalias.iterrows():
            print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD (z-score: {datos['produccion_normalizada']:.2f})")
    except NameError:
        print("No se han implementado las operaciones condicionales")

if __name__ == "__main__":
    main()
# Out:
#   File <tokenize>:27
#     print("\n=== Laboratorio 1: Indexación Multinivel y Jerarquías ===\n")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Archivo: lab_01_indexacion_multinivel.py
"""
Laboratorio 1: Indexación Multinivel y Jerarquías
Objetivo: Dominar las técnicas de indexación multinivel y operaciones jerárquicas
          con DataFrames para análisis avanzado de datos petroleros.

Este laboratorio utiliza datos del archivo pozos_multinivel.csv
"""
import pandas as pd
import numpy as np
from datetime import datetime

def main():
    # Cargar datos de ejemplo
    try:
        df_pozos = pd.read_csv('datos/pozos_multinivel.csv')
        print("Datos cargados exitosamente")
        print(f"Forma del DataFrame: {df_pozos.shape}")
        print(f"Columnas: {list(df_pozos.columns)}")
    except FileNotFoundError:
        print("Error: No se encontró el archivo 'datos/pozos_multinivel.csv'")
        return
    except Exception as e:
        print(f"Error al cargar datos: {e}")
        return

    print("\n=== Laboratorio 1: Indexación Multinivel y Jerarquías ===\n")

    # EJERCICIO 1: Crear MultiIndex jerárquico
    print("Ejercicio 1: Crear MultiIndex jerárquico")
    df_multi = df_pozos.copy()
    df_multi['fecha'] = pd.to_datetime(df_multi['fecha'])
    df_multi = df_multi.set_index(['campo', 'pozo', 'fecha'])

    # Imprimir resultados (no modificar)
    print(f"Forma del DataFrame con MultiIndex: {df_multi.shape}")
    print("Niveles del MultiIndex:")
    for i, level in enumerate(df_multi.index.names):
        print(f"  Nivel {i}: {level}")
    print("\nPrimeras filas del DataFrame con MultiIndex:")
    print(df_multi.head())

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 2: Selección jerárquica avanzada
    print("Ejercicio 2: Selección jerárquica avanzada")
    campo_libertad = df_multi.loc['Campo Libertad']
    pozo_lib001 = df_multi.loc[('Campo Libertad', 'LIB-001')]
    fecha_especifica = df_multi.loc[('Campo Libertad', 'LIB-001', pd.Timestamp('2024-01-01'))]

    print("a) Datos del Campo Libertad:")
    print(f"   Filas: {len(campo_libertad)}")
    print(f"   Pozos únicos: {campo_libertad.index.get_level_values('pozo').unique()}")

    print("\nb) Datos del pozo LIB-001 en Campo Libertad:")
    print(f"   Filas: {len(pozo_lib001)}")
    print(f"   Fechas: {list(pozo_lib001.index.get_level_values('fecha'))}")

    print("\nc) Datos específicos de fecha:")
    print(f"   Producción diaria: {fecha_especifica['produccion_diaria']} BPD")
    print(f"   Presión de cabeza: {fecha_especifica['presion_cabeza']} PSI")

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 3: Operaciones por niveles del MultiIndex
    print("Ejercicio 3: Operaciones por niveles del MultiIndex")
    # a) Producción promedio por campo
    produccion_por_campo = df_multi.groupby(level='campo')['produccion_diaria'].mean()
    # b) Producción promedio por pozo (manteniendo la jerarquía)
    produccion_por_pozo = df_multi.groupby(level=['campo', 'pozo'])['produccion_diaria'].mean()
    # c) Pozo con mayor producción por campo
    mejor_pozo_por_campo = df_multi.groupby(level='campo')['produccion_diaria'].agg(['mean', 'idxmax'])

    print("a) Producción promedio por campo:")
    for campo, produccion in produccion_por_campo.items():
        print(f"   {campo}: {produccion:.2f} BPD")

    print("\nb) Producción promedio por pozo:")
    for (campo, pozo), produccion in produccion_por_pozo.items():
        print(f"   {campo} - {pozo}: {produccion:.2f} BPD")

    print("\nc) Mejor pozo por campo:")
    for campo in df_multi.index.get_level_values('campo').unique():
        mejor_idx = mejor_pozo_por_campo.loc[campo, 'idxmax']
        mejor_pozo = mejor_idx[1]  # El pozo está en el segundo nivel
        mejor_produccion = mejor_pozo_por_campo.loc[campo, 'mean']
        print(f"   {campo}: {mejor_pozo} ({mejor_produccion:.2f} BPD)")

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 4: Reestructuración de datos (Pivot y Stack/Unstack)
    print("Ejercicio 4: Reestructuración de datos (Pivot y Stack/Unstack)")
    # a) Pivot table
    df_pivot = df_pozos.pivot_table(
        index='campo',
        columns='pozo',
        values='produccion_diaria',
        aggfunc='mean'
    )
    # b) Unstack
    df_unstacked = df_multi['produccion_diaria'].unstack(level='pozo')
    # c) Stack
    df_stacked = df_unstacked.stack()

    print("a) Pivot table (producción promedio por campo y pozo):")
    print(df_pivot)
    print("\nb) DataFrame unstacked (pozos como columnas):")
    print(df_unstacked)
    print("\nc) DataFrame re-stacked:")
    print(df_stacked.head(10))

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 5: Análisis comparativo avanzado
    print("Ejercicio 5: Análisis comparativo avanzado")
    # a) Eficiencia operacional por campo
    df_multi['eficiencia'] = df_multi['produccion_diaria'] / df_multi['horas_operacion']
    eficiencia_por_campo = df_multi.groupby(level='campo')['eficiencia'].mean()
    # b) Pozos con mayor variabilidad
    variabilidad_pozos = df_multi.groupby(level=['campo', 'pozo'])['produccion_diaria'].agg(['mean', 'std'])
    variabilidad_pozos['coeficiente_variacion'] = variabilidad_pozos['std'] / variabilidad_pozos['mean']
    # c) Ranking de campos
    ranking_campos = df_multi.groupby(level='campo').agg({
        'produccion_diaria': ['mean', 'sum'],
        'eficiencia_bomba': 'mean',
        'agua_cut': 'mean'
    }).round(2)

    print("a) Eficiencia operacional por campo:")
    for campo, eficiencia in eficiencia_por_campo.items():
        print(f"   {campo}: {eficiencia:.2f} BPD/hora")

    print("\nb) Pozos con mayor variabilidad (CV > 0.1):")
    pozos_variables = variabilidad_pozos[variabilidad_pozos['coeficiente_variacion'] > 0.1]
    for (campo, pozo), datos in pozos_variables.iterrows():
        print(f"   {campo} - {pozo}: CV = {datos['coeficiente_variacion']:.3f}")

    print("\nc) Ranking de campos por rendimiento:")
    print(ranking_campos)

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 6: Operaciones condicionales con MultiIndex
    print("Ejercicio 6: Operaciones condicionales con MultiIndex")
    # a) Marca los pozos con producción por encima del promedio de su campo
    df_multi['sobre_promedio'] = df_multi.groupby(level='campo')['produccion_diaria'].transform(
        lambda x: x > x.mean()
    )
    # b) Desviación estandarizada de producción por campo
    df_multi['produccion_normalizada'] = df_multi.groupby(level='campo')['produccion_diaria'].transform(
        lambda x: (x - x.mean()) / x.std()
    )
    # c) Anomalías
    anomalias = df_multi[abs(df_multi['produccion_normalizada']) > 2]

    print("a) Pozos con producción sobre el promedio de su campo:")
    pozos_sobre_promedio = df_multi[df_multi['sobre_promedio'] == True]
    for (campo, pozo, fecha), datos in pozos_sobre_promedio.iterrows():
        print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD")

    print(f"\nb) Estadísticas de normalización:")
    print(f"   Media: {df_multi['produccion_normalizada'].mean():.3f}")
    print(f"   Desv. Est.: {df_multi['produccion_normalizada'].std():.3f}")

    print(f"\nc) Anomalías detectadas: {len(anomalias)} registros")
    for (campo, pozo, fecha), datos in anomalias.iterrows():
        print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD (z-score: {datos['produccion_normalizada']:.2f})")

if __name__ == "__main__":
    main()
# Out:
# Datos cargados exitosamente
# Forma del DataFrame: (27, 13)
# Columnas: ['campo', 'pozo', 'fecha', 'profundidad', 'presion_cabeza', 'temperatura', 'produccion_diaria', 'agua_cut', 'gas_oil_ratio', 'estado_pozo', 'tipo_pozo', 'operador', 'region']
#
# === Laboratorio 1: Indexación Multinivel y Jerarquías ===
#
# Ejercicio 1: Crear MultiIndex jerárquico
# Forma del DataFrame con MultiIndex: (27, 10)
# Niveles del MultiIndex:
#   Nivel 0: campo
#   Nivel 1: pozo
#   Nivel 2: fecha
#
# Primeras filas del DataFrame con MultiIndex:
#                                    profundidad  presion_cabeza  temperatura  \
# campo          pozo    fecha
# Campo Libertad LIB-001 2024-01-01         2500            1250           82
#                        2024-01-02         2500            1248           83
#                        2024-01-03         2500            1252           81
#                LIB-002 2024-01-01         2700            1320           85
#                        2024-01-02         2700            1315           84
#
#                                    produccion_diaria  agua_cut  gas_oil_ratio  \
# campo          pozo    fecha
# Campo Libertad LIB-001 2024-01-01                180      15.2            120
#                        2024-01-02                178      15.8            118
#                        2024-01-03                182      14.9            122
#                LIB-002 2024-01-01                210      12.5             95
#                        2024-01-02                208      12.8             94
#
#                                   estado_pozo   tipo_pozo    operador region
# campo          pozo    fecha
# Campo Libertad LIB-001 2024-01-01      Activo  Producción  Operador A   Meta
#                        2024-01-02      Activo  Producción  Operador A   Meta
#                        2024-01-03      Activo  Producción  Operador A   Meta
#                LIB-002 2024-01-01      Activo  Producción  Operador A   Meta
#                        2024-01-02      Activo  Producción  Operador A   Meta
#
# --------------------------------------------------
#
# Ejercicio 2: Selección jerárquica avanzada
# a) Datos del Campo Libertad:
#    Filas: 9
#    Pozos únicos: Index(['LIB-001', 'LIB-002', 'LIB-003'], dtype='object', name='pozo')
#
# b) Datos del pozo LIB-001 en Campo Libertad:
#    Filas: 3
#    Fechas: [Timestamp('2024-01-01 00:00:00'), Timestamp('2024-01-02 00:00:00'), Timestamp('2024-01-03 00:00:00')]
#
# c) Datos específicos de fecha:
#    Producción diaria: 180 BPD
#    Presión de cabeza: 1250 PSI
#
# --------------------------------------------------
#
# Ejercicio 3: Operaciones por niveles del MultiIndex
# a) Producción promedio por campo:
#    Campo Castilla: 300.00 BPD
#    Campo Esperanza: 155.00 BPD
#    Campo Libertad: 130.00 BPD
#    Campo Rubiales: 415.00 BPD
#
# b) Producción promedio por pozo:
#    Campo Castilla - CAS-001: 280.00 BPD
#    Campo Castilla - CAS-002: 320.00 BPD
#    Campo Esperanza - ESP-001: 310.00 BPD
#    Campo Esperanza - ESP-002: 0.00 BPD
#    Campo Libertad - LIB-001: 180.00 BPD
#    Campo Libertad - LIB-002: 210.00 BPD
#    Campo Libertad - LIB-003: 0.00 BPD
#    Campo Rubiales - RUB-001: 450.00 BPD
#    Campo Rubiales - RUB-002: 380.00 BPD
#
# c) Mejor pozo por campo:
#    Campo Libertad: LIB-002 (130.00 BPD)
#    Campo Esperanza: ESP-001 (155.00 BPD)
#    Campo Rubiales: RUB-001 (415.00 BPD)
#    Campo Castilla: CAS-002 (300.00 BPD)
#
# --------------------------------------------------
#
# Ejercicio 4: Reestructuración de datos (Pivot y Stack/Unstack)
# a) Pivot table (producción promedio por campo y pozo):
# pozo             CAS-001  CAS-002  ESP-001  ESP-002  LIB-001  LIB-002  \
# campo
# Campo Castilla     280.0    320.0      NaN      NaN      NaN      NaN
# Campo Esperanza      NaN      NaN    310.0      0.0      NaN      NaN
# Campo Libertad       NaN      NaN      NaN      NaN    180.0    210.0
# Campo Rubiales       NaN      NaN      NaN      NaN      NaN      NaN
#
# pozo             LIB-003  RUB-001  RUB-002
# campo
# Campo Castilla       NaN      NaN      NaN
# Campo Esperanza      NaN      NaN      NaN
# Campo Libertad       0.0      NaN      NaN
# Campo Rubiales       NaN    450.0    380.0
#
# b) DataFrame unstacked (pozos como columnas):
# pozo                        CAS-001  CAS-002  ESP-001  ESP-002  LIB-001  \
# campo           fecha
# Campo Castilla  2024-01-01    280.0    320.0      NaN      NaN      NaN
#                 2024-01-02    278.0    318.0      NaN      NaN      NaN
#                 2024-01-03    282.0    322.0      NaN      NaN      NaN
# Campo Esperanza 2024-01-01      NaN      NaN    310.0      0.0      NaN
#                 2024-01-02      NaN      NaN    308.0      0.0      NaN
#                 2024-01-03      NaN      NaN    312.0      0.0      NaN
# Campo Libertad  2024-01-01      NaN      NaN      NaN      NaN    180.0
#                 2024-01-02      NaN      NaN      NaN      NaN    178.0
#                 2024-01-03      NaN      NaN      NaN      NaN    182.0
# Campo Rubiales  2024-01-01      NaN      NaN      NaN      NaN      NaN
#                 2024-01-02      NaN      NaN      NaN      NaN      NaN
#                 2024-01-03      NaN      NaN      NaN      NaN      NaN
#
# pozo                        LIB-002  LIB-003  RUB-001  RUB-002
# campo           fecha
# Campo Castilla  2024-01-01      NaN      NaN      NaN      NaN
#                 2024-01-02      NaN      NaN      NaN      NaN
#                 2024-01-03      NaN      NaN      NaN      NaN
# Campo Esperanza 2024-01-01      NaN      NaN      NaN      NaN
#                 2024-01-02      NaN      NaN      NaN      NaN
#                 2024-01-03      NaN      NaN      NaN      NaN
# Campo Libertad  2024-01-01    210.0      0.0      NaN      NaN
#                 2024-01-02    208.0      0.0      NaN      NaN
#                 2024-01-03    212.0      0.0      NaN      NaN
# Campo Rubiales  2024-01-01      NaN      NaN    450.0    380.0
#                 2024-01-02      NaN      NaN    448.0    378.0
#                 2024-01-03      NaN      NaN    452.0    382.0
#
# c) DataFrame re-stacked:
# campo            fecha       pozo
# Campo Castilla   2024-01-01  CAS-001    280.0
#                              CAS-002    320.0
#                  2024-01-02  CAS-001    278.0
#                              CAS-002    318.0
#                  2024-01-03  CAS-001    282.0
#                              CAS-002    322.0
# Campo Esperanza  2024-01-01  ESP-001    310.0
#                              ESP-002      0.0
#                  2024-01-02  ESP-001    308.0
#                              ESP-002      0.0
# dtype: float64
#
# --------------------------------------------------
#
# Ejercicio 5: Análisis comparativo avanzado
# /tmp/ipykernel_10186/1613078883.py:48: PerformanceWarning: indexing past lexsort depth may impact performance.
#   pozo_lib001 = df_multi.loc[('Campo Libertad', 'LIB-001')]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/envs/petroleum-viz/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'horas_operacion'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 170
#     167         print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD (z-score: {datos['produccion_normalizada']:.2f})")
#     169 if __name__ == "__main__":
# --> 170     main()
#
# Cell In[35], line 117, in main()
#     115 print("Ejercicio 5: Análisis comparativo avanzado")
#     116 # a) Eficiencia operacional por campo
# --> 117 df_multi['eficiencia'] = df_multi['produccion_diaria'] / df_multi['horas_operacion']
#     118 eficiencia_por_campo = df_multi.groupby(level='campo')['eficiencia'].mean()
#     119 # b) Pozos con mayor variabilidad
#
# File /opt/conda/envs/petroleum-viz/lib/python3.9/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/conda/envs/petroleum-viz/lib/python3.9/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'horas_operacion'

# %%
# Archivo: lab_01_indexacion_multinivel.py
"""
Laboratorio 1: Indexación Multinivel y Jerarquías
Objetivo: Dominar las técnicas de indexación multinivel y operaciones jerárquicas
          con DataFrames para análisis avanzado de datos petroleros.

Este laboratorio utiliza datos del archivo pozos_multinivel.csv
"""
import pandas as pd
import numpy as np
from datetime import datetime

def main():
    # Cargar datos de ejemplo
    try:
        df_pozos = pd.read_csv('datos/pozos_multinivel.csv')
        print("Datos cargados exitosamente")
        print(f"Forma del DataFrame: {df_pozos.shape}")
        print(f"Columnas: {list(df_pozos.columns)}")
    except FileNotFoundError:
        print("Error: No se encontró el archivo 'datos/pozos_multinivel.csv'")
        return
    except Exception as e:
        print(f"Error al cargar datos: {e}")
        return

    print("\n=== Laboratorio 1: Indexación Multinivel y Jerarquías ===\n")

    # EJERCICIO 1: Crear MultiIndex jerárquico
    print("Ejercicio 1: Crear MultiIndex jerárquico")
    df_multi = df_pozos.copy()
    df_multi['fecha'] = pd.to_datetime(df_multi['fecha'])
    df_multi = df_multi.set_index(['campo', 'pozo', 'fecha'])

    print(f"Forma del DataFrame con MultiIndex: {df_multi.shape}")
    print("Niveles del MultiIndex:")
    for i, level in enumerate(df_multi.index.names):
        print(f"  Nivel {i}: {level}")
    print("\nPrimeras filas del DataFrame con MultiIndex:")
    print(df_multi.head())

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 2: Selección jerárquica avanzada
    print("Ejercicio 2: Selección jerárquica avanzada")
    campo_libertad = df_multi.loc['Campo Libertad']
    pozo_lib001 = df_multi.loc[('Campo Libertad', 'LIB-001')]
    fecha_especifica = df_multi.loc[('Campo Libertad', 'LIB-001', pd.Timestamp('2024-01-01'))]

    print("a) Datos del Campo Libertad:")
    print(f"   Filas: {len(campo_libertad)}")
    print(f"   Pozos únicos: {campo_libertad.index.get_level_values('pozo').unique()}")

    print("\nb) Datos del pozo LIB-001 en Campo Libertad:")
    print(f"   Filas: {len(pozo_lib001)}")
    print(f"   Fechas: {list(pozo_lib001.index.get_level_values('fecha'))}")

    print("\nc) Datos específicos de fecha:")
    print(f"   Producción diaria: {fecha_especifica['produccion_diaria']} BPD")
    print(f"   Presión de cabeza: {fecha_especifica['presion_cabeza']} PSI")

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 3: Operaciones por niveles del MultiIndex
    print("Ejercicio 3: Operaciones por niveles del MultiIndex")
    produccion_por_campo = df_multi.groupby(level='campo')['produccion_diaria'].mean()
    produccion_por_pozo = df_multi.groupby(level=['campo', 'pozo'])['produccion_diaria'].mean()
    mejor_pozo_por_campo = df_multi.groupby(level='campo')['produccion_diaria'].agg(['mean', 'idxmax'])

    print("a) Producción promedio por campo:")
    for campo, produccion in produccion_por_campo.items():
        print(f"   {campo}: {produccion:.2f} BPD")

    print("\nb) Producción promedio por pozo:")
    for (campo, pozo), produccion in produccion_por_pozo.items():
        print(f"   {campo} - {pozo}: {produccion:.2f} BPD")

    print("\nc) Mejor pozo por campo:")
    for campo in df_multi.index.get_level_values('campo').unique():
        mejor_idx = mejor_pozo_por_campo.loc[campo, 'idxmax']
        mejor_pozo = mejor_idx[1]  # El pozo está en el segundo nivel
        mejor_produccion = mejor_pozo_por_campo.loc[campo, 'mean']
        print(f"   {campo}: {mejor_pozo} ({mejor_produccion:.2f} BPD)")

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 4: Reestructuración de datos (Pivot y Stack/Unstack)
    print("Ejercicio 4: Reestructuración de datos (Pivot y Stack/Unstack)")
    df_pivot = df_pozos.pivot_table(
        index='campo',
        columns='pozo',
        values='produccion_diaria',
        aggfunc='mean'
    )
    df_unstacked = df_multi['produccion_diaria'].unstack(level='pozo')
    df_stacked = df_unstacked.stack()

    print("a) Pivot table (producción promedio por campo y pozo):")
    print(df_pivot)
    print("\nb) DataFrame unstacked (pozos como columnas):")
    print(df_unstacked)
    print("\nc) DataFrame re-stacked:")
    print(df_stacked.head(10))

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 5: Análisis comparativo avanzado
    print("Ejercicio 5: Análisis comparativo avanzado")
    df_multi['eficiencia'] = df_multi['produccion_diaria'] / df_multi['agua_cut']
    eficiencia_por_campo = df_multi.groupby(level='campo')['eficiencia'].mean()
    variabilidad_pozos = df_multi.groupby(level=['campo', 'pozo'])['produccion_diaria'].agg(['mean', 'std'])
    variabilidad_pozos['coeficiente_variacion'] = variabilidad_pozos['std'] / variabilidad_pozos['mean']
    ranking_campos = df_multi.groupby(level='campo').agg({
        'produccion_diaria': ['mean', 'sum'],
        'eficiencia': 'mean',
        'agua_cut': 'mean'
    }).round(2)

    print("a) Eficiencia operacional por campo:")
    for campo, eficiencia in eficiencia_por_campo.items():
        print(f"   {campo}: {eficiencia:.2f} BPD/%")

    print("\nb) Pozos con mayor variabilidad (CV > 0.1):")
    pozos_variables = variabilidad_pozos[variabilidad_pozos['coeficiente_variacion'] > 0.1]
    for (campo, pozo), datos in pozos_variables.iterrows():
        print(f"   {campo} - {pozo}: CV = {datos['coeficiente_variacion']:.3f}")

    print("\nc) Ranking de campos por rendimiento:")
    print(ranking_campos)

    print("\n" + "-"*50 + "\n")

    # EJERCICIO 6: Operaciones condicionales con MultiIndex
    print("Ejercicio 6: Operaciones condicionales con MultiIndex")
    df_multi['sobre_promedio'] = df_multi.groupby(level='campo')['produccion_diaria'].transform(
        lambda x: x > x.mean()
    )
    df_multi['produccion_normalizada'] = df_multi.groupby(level='campo')['produccion_diaria'].transform(
        lambda x: (x - x.mean()) / x.std()
    )
    anomalias = df_multi[abs(df_multi['produccion_normalizada']) > 2]

    print("a) Pozos con producción sobre el promedio de su campo:")
    pozos_sobre_promedio = df_multi[df_multi['sobre_promedio'] == True]
    for (campo, pozo, fecha), datos in pozos_sobre_promedio.iterrows():
        print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD")

    print(f"\nb) Estadísticas de normalización:")
    print(f"   Media: {df_multi['produccion_normalizada'].mean():.3f}")
    print(f"   Desv. Est.: {df_multi['produccion_normalizada'].std():.3f}")

    print(f"\nc) Anomalías detectadas: {len(anomalias)} registros")
    for (campo, pozo, fecha), datos in anomalias.iterrows():
        print(f"   {campo} - {pozo} ({fecha}): {datos['produccion_diaria']} BPD (z-score: {datos['produccion_normalizada']:.2f})")

if __name__ == "__main__":
    main()
# Out:
# Datos cargados exitosamente
# Forma del DataFrame: (27, 13)
# Columnas: ['campo', 'pozo', 'fecha', 'profundidad', 'presion_cabeza', 'temperatura', 'produccion_diaria', 'agua_cut', 'gas_oil_ratio', 'estado_pozo', 'tipo_pozo', 'operador', 'region']
#
# === Laboratorio 1: Indexación Multinivel y Jerarquías ===
#
# Ejercicio 1: Crear MultiIndex jerárquico
# Forma del DataFrame con MultiIndex: (27, 10)
# Niveles del MultiIndex:
#   Nivel 0: campo
#   Nivel 1: pozo
#   Nivel 2: fecha
#
# Primeras filas del DataFrame con MultiIndex:
#                                    profundidad  presion_cabeza  temperatura  \
# campo          pozo    fecha
# Campo Libertad LIB-001 2024-01-01         2500            1250           82
#                        2024-01-02         2500            1248           83
#                        2024-01-03         2500            1252           81
#                LIB-002 2024-01-01         2700            1320           85
#                        2024-01-02         2700            1315           84
#
#                                    produccion_diaria  agua_cut  gas_oil_ratio  \
# campo          pozo    fecha
# Campo Libertad LIB-001 2024-01-01                180      15.2            120
#                        2024-01-02                178      15.8            118
#                        2024-01-03                182      14.9            122
#                LIB-002 2024-01-01                210      12.5             95
#                        2024-01-02                208      12.8             94
#
#                                   estado_pozo   tipo_pozo    operador region
# campo          pozo    fecha
# Campo Libertad LIB-001 2024-01-01      Activo  Producción  Operador A   Meta
#                        2024-01-02      Activo  Producción  Operador A   Meta
#                        2024-01-03      Activo  Producción  Operador A   Meta
#                LIB-002 2024-01-01      Activo  Producción  Operador A   Meta
#                        2024-01-02      Activo  Producción  Operador A   Meta
#
# --------------------------------------------------
#
# Ejercicio 2: Selección jerárquica avanzada
# a) Datos del Campo Libertad:
#    Filas: 9
#    Pozos únicos: Index(['LIB-001', 'LIB-002', 'LIB-003'], dtype='object', name='pozo')
#
# b) Datos del pozo LIB-001 en Campo Libertad:
#    Filas: 3
#    Fechas: [Timestamp('2024-01-01 00:00:00'), Timestamp('2024-01-02 00:00:00'), Timestamp('2024-01-03 00:00:00')]
#
# c) Datos específicos de fecha:
#    Producción diaria: 180 BPD
#    Presión de cabeza: 1250 PSI
#
# --------------------------------------------------
#
# Ejercicio 3: Operaciones por niveles del MultiIndex
# a) Producción promedio por campo:
#    Campo Castilla: 300.00 BPD
#    Campo Esperanza: 155.00 BPD
#    Campo Libertad: 130.00 BPD
#    Campo Rubiales: 415.00 BPD
#
# b) Producción promedio por pozo:
#    Campo Castilla - CAS-001: 280.00 BPD
#    Campo Castilla - CAS-002: 320.00 BPD
#    Campo Esperanza - ESP-001: 310.00 BPD
#    Campo Esperanza - ESP-002: 0.00 BPD
#    Campo Libertad - LIB-001: 180.00 BPD
#    Campo Libertad - LIB-002: 210.00 BPD
#    Campo Libertad - LIB-003: 0.00 BPD
#    Campo Rubiales - RUB-001: 450.00 BPD
#    Campo Rubiales - RUB-002: 380.00 BPD
#
# c) Mejor pozo por campo:
#    Campo Libertad: LIB-002 (130.00 BPD)
#    Campo Esperanza: ESP-001 (155.00 BPD)
#    Campo Rubiales: RUB-001 (415.00 BPD)
#    Campo Castilla: CAS-002 (300.00 BPD)
#
# --------------------------------------------------
#
# Ejercicio 4: Reestructuración de datos (Pivot y Stack/Unstack)
# a) Pivot table (producción promedio por campo y pozo):
# pozo             CAS-001  CAS-002  ESP-001  ESP-002  LIB-001  LIB-002  \
# campo
# Campo Castilla     280.0    320.0      NaN      NaN      NaN      NaN
# Campo Esperanza      NaN      NaN    310.0      0.0      NaN      NaN
# Campo Libertad       NaN      NaN      NaN      NaN    180.0    210.0
# Campo Rubiales       NaN      NaN      NaN      NaN      NaN      NaN
#
# pozo             LIB-003  RUB-001  RUB-002
# campo
# Campo Castilla       NaN      NaN      NaN
# Campo Esperanza      NaN      NaN      NaN
# Campo Libertad       0.0      NaN      NaN
# Campo Rubiales       NaN    450.0    380.0
#
# b) DataFrame unstacked (pozos como columnas):
# pozo                        CAS-001  CAS-002  ESP-001  ESP-002  LIB-001  \
# campo           fecha
# Campo Castilla  2024-01-01    280.0    320.0      NaN      NaN      NaN
#                 2024-01-02    278.0    318.0      NaN      NaN      NaN
#                 2024-01-03    282.0    322.0      NaN      NaN      NaN
# Campo Esperanza 2024-01-01      NaN      NaN    310.0      0.0      NaN
#                 2024-01-02      NaN      NaN    308.0      0.0      NaN
#                 2024-01-03      NaN      NaN    312.0      0.0      NaN
# Campo Libertad  2024-01-01      NaN      NaN      NaN      NaN    180.0
#                 2024-01-02      NaN      NaN      NaN      NaN    178.0
#                 2024-01-03      NaN      NaN      NaN      NaN    182.0
# Campo Rubiales  2024-01-01      NaN      NaN      NaN      NaN      NaN
#                 2024-01-02      NaN      NaN      NaN      NaN      NaN
#                 2024-01-03      NaN      NaN      NaN      NaN      NaN
#
# pozo                        LIB-002  LIB-003  RUB-001  RUB-002
# campo           fecha
# Campo Castilla  2024-01-01      NaN      NaN      NaN      NaN
#                 2024-01-02      NaN      NaN      NaN      NaN
#                 2024-01-03      NaN      NaN      NaN      NaN
# Campo Esperanza 2024-01-01      NaN      NaN      NaN      NaN
#                 2024-01-02      NaN      NaN      NaN      NaN
#                 2024-01-03      NaN      NaN      NaN      NaN
# Campo Libertad  2024-01-01    210.0      0.0      NaN      NaN
#                 2024-01-02    208.0      0.0      NaN      NaN
#                 2024-01-03    212.0      0.0      NaN      NaN
# Campo Rubiales  2024-01-01      NaN      NaN    450.0    380.0
#                 2024-01-02      NaN      NaN    448.0    378.0
#                 2024-01-03      NaN      NaN    452.0    382.0
#
# c) DataFrame re-stacked:
# campo            fecha       pozo
# Campo Castilla   2024-01-01  CAS-001    280.0
#                              CAS-002    320.0
#                  2024-01-02  CAS-001    278.0
#                              CAS-002    318.0
#                  2024-01-03  CAS-001    282.0
#                              CAS-002    322.0
# Campo Esperanza  2024-01-01  ESP-001    310.0
#                              ESP-002      0.0
#                  2024-01-02  ESP-001    308.0
#                              ESP-002      0.0
# dtype: float64
#
# --------------------------------------------------
#
# Ejercicio 5: Análisis comparativo avanzado
# a) Eficiencia operacional por campo:
#    Campo Castilla: 17.45 BPD/%
#    Campo Esperanza: 36.51 BPD/%
#    Campo Libertad: 14.29 BPD/%
#    Campo Rubiales: 17.47 BPD/%
#
# b) Pozos con mayor variabilidad (CV > 0.1):
#
# c) Ranking de campos por rendimiento:
#                 produccion_diaria       eficiencia agua_cut
#                              mean   sum       mean     mean
# campo
# Campo Castilla              300.0  1800      17.45    17.35
# Campo Esperanza             155.0   930      36.51     4.25
# Campo Libertad              130.0  1170      14.29     9.27
# Campo Rubiales              415.0  2490      17.47    23.73
#
# --------------------------------------------------
#
# Ejercicio 6: Operaciones condicionales con MultiIndex
# a) Pozos con producción sobre el promedio de su campo:
#    Campo Libertad - LIB-001 (2024-01-01 00:00:00): 180 BPD
#    Campo Libertad - LIB-001 (2024-01-02 00:00:00): 178 BPD
#    Campo Libertad - LIB-001 (2024-01-03 00:00:00): 182 BPD
#    Campo Libertad - LIB-002 (2024-01-01 00:00:00): 210 BPD
#    Campo Libertad - LIB-002 (2024-01-02 00:00:00): 208 BPD
#    Campo Libertad - LIB-002 (2024-01-03 00:00:00): 212 BPD
#    Campo Esperanza - ESP-001 (2024-01-01 00:00:00): 310 BPD
#    Campo Esperanza - ESP-001 (2024-01-02 00:00:00): 308 BPD
#    Campo Esperanza - ESP-001 (2024-01-03 00:00:00): 312 BPD
#    Campo Rubiales - RUB-001 (2024-01-01 00:00:00): 450 BPD
#    Campo Rubiales - RUB-001 (2024-01-02 00:00:00): 448 BPD
#    Campo Rubiales - RUB-001 (2024-01-03 00:00:00): 452 BPD
#    Campo Castilla - CAS-002 (2024-01-01 00:00:00): 320 BPD
#    Campo Castilla - CAS-002 (2024-01-02 00:00:00): 318 BPD
#    Campo Castilla - CAS-002 (2024-01-03 00:00:00): 322 BPD
#
# b) Estadísticas de normalización:
#    Media: -0.000
#    Desv. Est.: 0.941
#
# c) Anomalías detectadas: 0 registros
# /tmp/ipykernel_10186/3315637055.py:47: PerformanceWarning: indexing past lexsort depth may impact performance.
#   pozo_lib001 = df_multi.loc[('Campo Libertad', 'LIB-001')]

# %%
# Archivo: lab_01_indexacion_multinivel.py
"""

def main():
    # Cargar datos de ejemplo
    try:
        df_pozos = pd.read_csv('datos/pozos_multinivel.csv')
        print("Datos cargados exitosamente")
        print(f"Forma del DataFrame: {df_pozos.shape}")
        print(f"Columnas: {list(df_pozos.columns)}")
    except FileNotFoundError:
        print("Error: No se encontró el archivo 'datos/pozos_multinivel.csv'")
        return
    except ImportError as e:
        print("Error de importación:", e)
        print("Asegúrate de instalar pandas y numpy con: pip install pandas numpy")
        return
    except Exception as e:
        print(f"Error al cargar datos: {e}")
        return

    print("\n=== Laboratorio 1: Indexación Multinivel y Jerarquías ===\n")

    # Validar columnas necesarias
    columnas_necesarias = {'campo', 'pozo', 'fecha', 'produccion_diaria', 'presion_cabeza', 'agua_cut'}
    if not columnas_necesarias.issubset(df_pozos.columns):
        print(f"Error: El archivo debe contener las columnas: {columnas_necesarias}")
        return

    # EJERCICIO 1: Crear MultiIndex jerárquico
    print("Ejercicio 1: Crear MultiIndex jerárquico")
    df_multi = df_pozos.copy()
    df_multi['fecha'] = pd.to_datetime(df_multi['fecha'], errors='coerce')
    df_multi = df_multi.set_index(['campo', 'pozo', 'fecha'])

    print(f"Forma del DataFrame con MultiIndex: {df_multi.shape}")
    print("Niveles del MultiIndex:")
    for i, level in enumerate(df_multi.index.names):
        print(f"  Nivel {i}: {level}")
    print("\nPrimeras filas del DataFrame con MultiIndex:")
    print(df_multi.head())

    print("\n" + "-"*50 + "\n")
# Out:
#   Cell In[42], line 45
#
#     ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
# EJERCICIO 2: Selección jerárquica avanzada
    print("Ejercicio 2: Selección jerárquica avanzada")
    try:
        campo_libertad = df_multi.loc['Campo Libertad']
        pozo_lib001 = df_multi.loc[('Campo Libertad', 'LIB-001')]
        fecha_especifica = df_multi.loc[('Campo Libertad', 'LIB-001', pd.Timestamp('2024-01-01'))]

        print("a) Datos del Campo Libertad:")
        print(f"   Filas: {len(campo_libertad)}")
        print(f"   Pozos únicos: {campo_libertad.index.get_level_values('pozo').unique()}")

        print("\nb) Datos del pozo LIB-001 en Campo Libertad:")
        print(f"   Filas: {len(pozo_lib001)}")
        print(f"   Fechas: {list(pozo_lib001.index.get_level_values('fecha'))}")

        print("\nc) Datos específicos de fecha:")
        print(f"   Producción diaria: {fecha_especifica['produccion_diaria']} BPD")
        print(f"   Presión de cabeza: {fecha_especifica['presion_cabeza']} PSI")
    except KeyError as e:
        print(f"Advertencia: No se encontró el valor en el índice: {e}")

    print("\n" + "-"*50 + "\n")
# Out:
#   Cell In[41], line 2
#     print("Ejercicio 2: Selección jerárquica avanzada")
#     ^
# IndentationError: unexpected indent
